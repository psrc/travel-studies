# %%
import pandas as pd

# %%
hh = pd.read_csv(r'J:\Projects\Surveys\HHTravel\Survey2015\Data\Household\PSRC2015_HH_2015-07-27_V1.1.csv')

# %%
trip = pd.read_csv(r'J:\Projects\Surveys\HHTravel\Survey2015\Data\Trips\PSRC2015_Trip_2015-07-27_V1.4.csv')
# Out:
# c:\Users\Brice\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\io\parsers.py:1170: DtypeWarning: Columns (57) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
trip_hh = pd.merge(trip,hh,on='hhid')

# %%
trip_hh.groupby('mode').sum()
# Out:
#       chk     order        personID            tripID          hhid  pernum  \
# mode
# 1      89  77263464  10881203176707  1088120317695738  108812031665   10207
# 2      18  48696291   6874167812254   687416781243314   68741678020   10254
# 3       3  12227066   1794368826687   179436882673766   17943688247    1987
# 4     NaN    140677     22765517826     2276551782633     227655178      26
# 5       1    562748     94576538696     9457653869778     945765386      96
# 6       1   2848876    442655990337    44265599034644    4426559899     437
# 7      14  33833471   5396015642221   539601564226391   53960156365    5623
# 8      28  11907657   1996866465499   199686646554096   19968664636    1899
# 9     NaN    785254    123163053612    12316305361500    1231630535     112
# 10      3    664627     88821986086     8882198608820     888219860      86
# 11    NaN     33742      4330884205      433088420513      43308842       5
# ...

# %%
pd.pivot_table(trip_hh, values='expwt_final', columns='h_rgc_name', aggfunc='sum')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-080ad2f84326> in <module>()
# ----> 1 pd.pivot_table(trip_hh, values='expwt_final', columns='h_rgc_name', aggfunc='sum')
#
# c:\Users\Brice\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\tools\pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna)
#     145     # discard the top level
#     146     if values_passed and not values_multi:
# --> 147         table = table[values[0]]
#     148
#     149     if len(index) == 0 and len(columns) > 0:
#
# c:\Users\Brice\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# ...
