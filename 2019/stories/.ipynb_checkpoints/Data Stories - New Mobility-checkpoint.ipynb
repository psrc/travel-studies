# %%
#03/03/2020
#Seattle Data Stories - New Mobility Story
#Who is using ride-hailing apps,carsharing services, and home delivery services?
#Data Used: PSRC HHTS 2019

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
#Loading the data
import pandas as pd
import pyodbc
# File names and directories
survey_dir = 'J:/Projects/Surveys/HHTravel/Survey2019/Data/PSRC_2019_HTS_Deliverable_022020/Weighted_Data_022020/'
hh_file_name = '1_household.csv'
person_file_name = '2_person.csv'
vehicle_file_name = '3_vehicle.csv'
day_file_name = '4_day.csv'
trip_file_name = '5_trip.csv'

#sql_conn = pyodbc.connect('DRIVER={SQL Server}; SERVER=AWS-PROD-SQL\COHO;DATABASE=HouseholdTravelSurvey2019;trusted_connection=true')
#trip_table_name = "HHSurvey.Trip"
#trip  = pd.read_sql('SELECT * FROM '+trip_table_name, con = sql_conn)

hh_weight_2017 = 'hh_wt_revised'
hh_weight_2019 = 'hh_wt_2019'
hh_weight_combined = 'hh_wt_combined'
hh_weight_names =[hh_weight_2017, hh_weight_2019, hh_weight_combined]

day_weight_2017 = 'hh_day_wt_revised'
day_weight_2019 = 'hh_day_wt_2019'
day_weight_combined = 'hh_day_wt_combined'
day_weight_names =[day_weight_2017, day_weight_2019, day_weight_combined]

trip_weight_2017 = 'trip_weight_revised'
trip_weight_2019 ='trip_wt_2019'
trip_weight_combined = 'trip_wt_combined'
trip_weight_names =[trip_weight_2017, trip_weight_2019, trip_weight_combined]

codebook_file = 'Combined_Codebook_022020.xlsx'
output_file_hh = 'C:/Users/pbutrina/Documents/GitHub/travel-studies/2019/summary/hh_summary.xlsx'
output_file_person= 'C:/Users/pbutrina/Documents/GitHub/travel-studies/2019/summary/person_summary.xlsx'
output_file_day= 'C:/Users/pbutrina/Documents/GitHub/travel-studies/2019/summary/day_summary.xlsx'
output_file_trip= 'C:/Users/pbutrina/Documents/GitHub/travel-studies/2019/summary/trip_summary.xlsx'

# %%
def merge_hh_person_trip(hh,person,trip):
    hh_person =pd.merge(hh, person, on= 'hhid', suffixes=['', 'person'], how ='right')
    hh_person_trip = pd.merge(hh_person, trip,on='personid', suffixes=['','trip'], how ='right')
    return hh_person_trip

def merge_hh_person(hh, person):
    hh_person =pd.merge(hh, person, on= 'hhid', suffixes=['', 'person'], how ='right')
    return hh_person

# %%
hh = pd.read_csv(survey_dir+hh_file_name, encoding = 'latin-1')
person= pd.read_csv(survey_dir+person_file_name, encoding = 'latin-1')
trip = pd.read_csv(survey_dir+trip_file_name, encoding = 'latin-1')
day= pd.read_csv(survey_dir+day_file_name, encoding='latin-1')
# Out:
# C:\Users\pbutrina\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (8,44,45,53,56,57,65,72,73,81) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\pbutrina\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (0,10,11,20,24,37,39,106,112,118,120,121,128) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\pbutrina\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (14,15,21,23,34,45) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
codebook_values = pd.read_excel(survey_dir+codebook_file, sheet_name='Values')
codebook_variables =pd.read_excel(survey_dir+codebook_file, sheet_name='Data Overview')

# %%
person_detail = merge_hh_person(hh, person)
trip_detail = merge_hh_person_trip(hh, person, trip)

# %%
def lookup_codes(grouped_total, item,name):
    values=codebook_values.loc[codebook_values['variable']==item]
    variable =codebook_variables.loc[codebook_variables['variable']==item, 'description'].values[0]
    missing_values_df = pd.DataFrame({'variable': [item, item, item],'value':[-9999,-9998, 995], 'label':
                                         ['Missing:Technical Error', 'Missing: Non-response', 'Missing:Skip logic']})
    values = values.append(missing_values_df)
    summary=pd.merge(values, grouped_total,left_on='value', right_on=item)
    summary[item+'_variable']=variable
    summary = summary.rename(columns = {'label':name, 'value':name+'_value'})
    return summary

# %%
#Choose PUMAs that are located in Seattle
person_detail_Seattle = person_detail[(person_detail["final_home_puma10"] >= 11601) & (person_detail["final_home_puma10"] <= 11605)]

# %%
#Checking number of rows in every PUMA selected to see if it matches raw data (it should match)
person_detail_Seattle.groupby(['final_home_puma10']).count()
# Out:
#                    recid  hhid  survey_year  cityofredmond  cityofseattle  \
# final_home_puma10
# 11601                758  1562         1562            804           1562
# 11602                461  1129         1129            668           1129
# 11603               1045  1908         1908            863           1908
# 11604                624  1201         1201            577           1201
# 11605                503  1038         1038            535           1038
#
#                    psrc  hhgroup  sample_segment  sample_lat  sample_lng  ...  \
# final_home_puma10                                                         ...
# 11601              1562     1562            1562         758         758  ...
# 11602              1129     1129            1129         461         461  ...
# 11603              1908     1908            1908        1045        1045  ...
# 11604              1201     1201            1201         624         624  ...
# 11605              1038     1038            1038         503         503  ...
#
#                    num_tripsperson  nwkdaysperson  hh_wt_revisedperson  \
# final_home_puma10
# 11601                         1562           1562                  800
# 11602                         1129           1129                  668
# 11603                         1908           1908                  863
# 11604                         1201           1201                  577
# 11605                         1038           1038                  535
#
#                    hh_day_wt_revisedperson  \
# final_home_puma10
# 11601                                  800
# 11602                                  668
# 11603                                  863
# 11604                                  577
# 11605                                  535
#
#                    initial_expansion_factor_combinedperson  \
# final_home_puma10
# 11601                                                 1562
# 11602                                                 1129
# 11603                                                 1908
# 11604                                                 1201
# 11605                                                 1038
#
#                    hh_wt_combinedperson  initial_expansion_factor_2019person  \
# final_home_puma10
# 11601                              1562                                 1562
# 11602                              1129                                 1129
# 11603                              1908                                 1908
# 11604                              1201                                 1201
# 11605                              1038                                 1038
#
#                    hh_wt_2019person  hh_day_wt_combinedperson  \
# final_home_puma10
# 11601                          1562                      1562
# 11602                          1129                      1129
# 11603                          1908                      1908
# 11604                          1201                      1201
# 11605                          1038                      1038
#
#                    hh_day_wt_2019person
# final_home_puma10
# 11601                              1562
# 11602                              1129
# 11603                              1908
# 11604                              1201
# 11605                              1038
#
# [5 rows x 251 columns]

# %%
#The share of all people who is using ride-hailing
person_detail_df = lookup_codes(person_detail_Seattle,'mode_freq_5')
tnc_freq_seattle =person_detail_df.groupby(['label']).sum()['hh_wt_2019'].reset_index()

# %%
person_detail_df = lookup_codes(person_detail_Seattle,'mode_freq_5',"TNC_Freq")
person_detail_df
# Out:
#          variable  TNC_Freq_value            TNC_Freq   recid       hhid  \
# 0     mode_freq_5               1       6-7 days/week     NaN   17100834
# 1     mode_freq_5               1       6-7 days/week     NaN   17100957
# 2     mode_freq_5               1       6-7 days/week     NaN   17116572
# 3     mode_freq_5               1       6-7 days/week     NaN   17126013
# 4     mode_freq_5               1       6-7 days/week     NaN   17128073
# ...           ...             ...                 ...     ...        ...
# 6399  mode_freq_5             995  Missing:Skip logic  3052.0  191005786
# 6400  mode_freq_5             995  Missing:Skip logic  3061.0  191006149
# 6401  mode_freq_5             995  Missing:Skip logic  3061.0  191006149
# 6402  mode_freq_5             995  Missing:Skip logic  3076.0  191038667
# 6403  mode_freq_5             995  Missing:Skip logic  3076.0  191038667
#
#       survey_year  cityofredmond  cityofseattle  psrc  hhgroup  ...  \
# 0            2017            0.0              1     0        1  ...
# 1            2017            0.0              1     0        2  ...
# 2            2017            0.0              1     0        2  ...
# 3            2017            0.0              1     0        1  ...
# 4            2017            0.0              1     0        2  ...
# ...           ...            ...            ...   ...      ...  ...
# 6399         2019            NaN              1     0        1  ...
# 6400         2019            NaN              1     0        1  ...
# 6401         2019            NaN              1     0        1  ...
# 6402         2019            NaN              1     0        1  ...
# 6403         2019            NaN              1     0        1  ...
#
#       nwkdaysperson  hh_wt_revisedperson  hh_day_wt_revisedperson  \
# 0                 1             7.112845                 7.112845
# 1                 1            50.580761                50.580761
# 2                 1             6.454744                 6.454744
# 3                 4            25.074854                 6.268714
# 4                 1            29.037464                29.037464
# ...             ...                  ...                      ...
# 6399              3                  NaN                      NaN
# 6400              4                  NaN                      NaN
# 6401              4                  NaN                      NaN
# 6402              4                  NaN                      NaN
# 6403              4                  NaN                      NaN
#
#      initial_expansion_factor_combinedperson  hh_wt_combinedperson  \
# 0                                  13.208121             66.040604
# 1                                  86.469251             22.058057
# 2                                   7.422187             10.881897
# 3                                  47.543561             12.128225
# 4                                  46.361112            231.805562
# ...                                      ...                   ...
# 6399                               46.880854             12.218658
# 6400                               46.880854             12.218658
# 6401                               46.880854             12.218658
# 6402                               46.880854             12.218658
# 6403                               46.880854             12.218658
#
#       initial_expansion_factor_2019person  hh_wt_2019person  \
# 0                                0.000000          0.000000
# 1                                0.000000          0.000000
# 2                                0.000000          0.000000
# 3                                0.000000          0.000000
# 4                                0.000000          0.000000
# ...                                   ...               ...
# 6399                            97.319355         25.354003
# 6400                            97.319355         25.354003
# 6401                            97.319355         25.354003
# 6402                            97.319355         25.354003
# 6403                            97.319355         25.354003
#
#      hh_day_wt_combinedperson  hh_day_wt_2019person  \
# 0                   66.040604              0.000000
# 1                   22.058057              0.000000
# 2                   10.881897              0.000000
# 3                    3.032056              0.000000
# 4                  231.805562              0.000000
# ...                       ...                   ...
# 6399                 4.072886              8.451334
# 6400                 3.054665              6.338501
# 6401                 3.054665              6.338501
# 6402                 3.054665              6.338501
# 6403                 3.054665              6.338501
#
#                       mode_freq_5_variable
# 0     Times used rideshare in past 30 days
# 1     Times used rideshare in past 30 days
# 2     Times used rideshare in past 30 days
# 3     Times used rideshare in past 30 days
# 4     Times used rideshare in past 30 days
# ...                                    ...
# 6399  Times used rideshare in past 30 days
# 6400  Times used rideshare in past 30 days
# 6401  Times used rideshare in past 30 days
# 6402  Times used rideshare in past 30 days
# 6403  Times used rideshare in past 30 days
#
# [6404 rows x 256 columns]

# %%
tnc_freq_seattle['Share'] = 0
for i in range(0,len(tnc_freq_seattle.index)):
    tnc_freq_seattle.iloc[i,2] =tnc_freq_seattle.iloc[i,1]/ (tnc_freq_seattle['hh_wt_2019'].sum())*100

# %%
tnc_freq_seattle.sort_values(by=['Share'], inplace=True, ascending=False)
tnc_freq_seattle
# Out:
#                                     label     hh_wt_2019      Share
# 6                         I never do this  302415.645935  43.276547
# 1           1-3 times in the past 30 days  128726.110251  18.421076
# 8                      Missing:Skip logic  110596.967333  15.826744
# 5  I do this, but not in the past 30 days   84255.659584  12.057227
# 2                           2-4 days/week   36427.097627   5.212822
# 0                              1 day/week   31044.253288   4.442522
# 4                           6-7 days/week    2295.893224   0.328549
# 3                             5 days/week    1869.178235   0.267485
# 7                   Missing: Non-response    1167.194522   0.167029

# %%
#Visualization
plt.bar(tnc_freq_seattle["label"],tnc_freq_seattle["Share"])
plt.axis([0, 6, 0, 100])
plt.xticks(rotation=90)
plt.xlabel('Frequency')
plt.ylabel('Share, %')
#plt.title("TNC Frequency, Seattle\nData Source: PSRC HHTS 2019")
title = "Frequency of Rideshre Use, Seattle"
subtitle = "Data Source: PSRC HHTS 2019"
plt.suptitle(title, y=1.02, fontsize=18)
plt.title(subtitle, fontsize=10)
# Out:
# Text(0.5, 1.0, 'Data Source: PSRC HHTS 2019')

# %%
tnc_freq_seattle
# Out:
#                                     label     hh_wt_2019      Share
# 6                         I never do this  302415.645935  43.276547
# 1           1-3 times in the past 30 days  128726.110251  18.421076
# 8                      Missing:Skip logic  110596.967333  15.826744
# 5  I do this, but not in the past 30 days   84255.659584  12.057227
# 2                           2-4 days/week   36427.097627   5.212822
# 0                              1 day/week   31044.253288   4.442522
# 4                           6-7 days/week    2295.893224   0.328549
# 3                             5 days/week    1869.178235   0.267485
# 7                   Missing: Non-response    1167.194522   0.167029

# %%
tnc_freq_seattle=tnc_freq_seattle[tnc_freq_seattle.TNC_Freq != 'Missing:Skip logic']
tnc_freq_seattle=tnc_freq_seattle[tnc_freq_seattle.TNC_Freq != 'Missing: Non-response']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-756f6f49e74c> in <module>
# ----> 1 tnc_freq_seattle=tnc_freq_seattle[tnc_freq_seattle.TNC_Freq != 'Missing:Skip logic']
#       2 tnc_freq_seattle=tnc_freq_seattle[tnc_freq_seattle.TNC_Freq != 'Missing: Non-response']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'TNC_Freq'

# %%
#grouped by gender

# %%
person_detail_df = lookup_codes(person_detail_df,'gender',"Gender")
#person_detail_df =person_detail_df.rename(columns = {'label_x':'Gender', 'label_y':'TNC_Freq'})
tnc_gender_seattle =person_detail_df.groupby(['TNC_Freq','Gender']).sum()['hh_wt_2019'].reset_index()

# %%
tnc_gender_seattle
# Out:
#                                   TNC_Freq                Gender  \
# 0                               1 day/week               Another
# 1                               1 day/week                Female
# 2                               1 day/week                  Male
# 3                               1 day/week  Prefer not to answer
# 4            1-3 times in the past 30 days               Another
# 5            1-3 times in the past 30 days                Female
# 6            1-3 times in the past 30 days                  Male
# 7            1-3 times in the past 30 days  Prefer not to answer
# 8                            2-4 days/week               Another
# 9                            2-4 days/week                Female
# 10                           2-4 days/week                  Male
# 11                           2-4 days/week  Prefer not to answer
# 12                             5 days/week                Female
# 13                             5 days/week                  Male
# 14                             5 days/week  Prefer not to answer
# 15                           6-7 days/week               Another
# 16                           6-7 days/week                Female
# 17                           6-7 days/week                  Male
# 18  I do this, but not in the past 30 days               Another
# 19  I do this, but not in the past 30 days                Female
# 20  I do this, but not in the past 30 days                  Male
# 21  I do this, but not in the past 30 days  Prefer not to answer
# 22                         I never do this               Another
# 23                         I never do this                Female
# 24                         I never do this                  Male
# 25                         I never do this  Prefer not to answer
# 26                   Missing: Non-response                Female
# 27                   Missing: Non-response                  Male
# 28                      Missing:Skip logic               Another
# 29                      Missing:Skip logic                Female
# 30                      Missing:Skip logic                  Male
# 31                      Missing:Skip logic  Prefer not to answer
#
#        hh_wt_2019
# 0      305.103199
# 1     9804.810409
# 2    20868.177324
# 3       66.162356
# 4      313.278613
# 5    66232.272487
# 6    61591.314952
# 7      589.244198
# 8       25.946069
# 9    16955.429595
# 10   18920.847794
# 11     524.874169
# 12    1118.513374
# 13     676.900699
# 14      73.764162
# 15       0.000000
# 16     998.088721
# 17    1297.804503
# 18    1300.914208
# 19   53204.426540
# 20   28104.842347
# 21    1645.476489
# 22     994.845054
# 23  122558.957386
# 24  171008.218122
# 25    7853.625373
# 26     655.175391
# 27     512.019131
# 28     101.205677
# 29   61203.439960
# 30   47696.454489
# 31    1595.867207

# %%
tnc_gender_seattle['Share'] = 0
for i in range(0,len(tnc_gender_seattle.index)):
    tnc_gender_seattle.iloc[i,3] =tnc_gender_seattle.iloc[i,2]/ (tnc_gender_seattle['hh_wt_2019'].sum())*100

# %%
tnc_gender_seattle.sort_values(by=['TNC_Freq'], inplace=True, ascending=False)
tnc_gender_seattle
# Out:
#                                   TNC_Freq                Gender  \
# 31                      Missing:Skip logic  Prefer not to answer
# 30                      Missing:Skip logic                  Male
# 29                      Missing:Skip logic                Female
# 28                      Missing:Skip logic               Another
# 27                   Missing: Non-response                  Male
# 26                   Missing: Non-response                Female
# 25                         I never do this  Prefer not to answer
# 24                         I never do this                  Male
# 23                         I never do this                Female
# 22                         I never do this               Another
# 21  I do this, but not in the past 30 days  Prefer not to answer
# 20  I do this, but not in the past 30 days                  Male
# 19  I do this, but not in the past 30 days                Female
# 18  I do this, but not in the past 30 days               Another
# 17                           6-7 days/week                  Male
# 16                           6-7 days/week                Female
# 15                           6-7 days/week               Another
# 14                             5 days/week  Prefer not to answer
# 13                             5 days/week                  Male
# 12                             5 days/week                Female
# 11                           2-4 days/week  Prefer not to answer
# 10                           2-4 days/week                  Male
# 9                            2-4 days/week                Female
# 8                            2-4 days/week               Another
# 7            1-3 times in the past 30 days  Prefer not to answer
# 6            1-3 times in the past 30 days                  Male
# 5            1-3 times in the past 30 days                Female
# 4            1-3 times in the past 30 days               Another
# 1                               1 day/week                Female
# 3                               1 day/week  Prefer not to answer
# 2                               1 day/week                  Male
# 0                               1 day/week               Another
#
#        hh_wt_2019      Share
# 31    1595.867207   0.228373
# 30   47696.454489   6.825500
# 29   61203.439960   8.758388
# 28     101.205677   0.014483
# 27     512.019131   0.073271
# 26     655.175391   0.093757
# 25    7853.625373   1.123876
# 24  171008.218122  24.471767
# 23  122558.957386  17.538539
# 22     994.845054   0.142365
# 21    1645.476489   0.235472
# 20   28104.842347   4.021884
# 19   53204.426540   7.613706
# 18    1300.914208   0.186165
# 17    1297.804503   0.185720
# 16     998.088721   0.142829
# 15       0.000000   0.000000
# 14      73.764162   0.010556
# 13     676.900699   0.096866
# 12    1118.513374   0.160062
# 11     524.874169   0.075111
# 10   18920.847794   2.707628
# 9    16955.429595   2.426371
# 8       25.946069   0.003713
# 7      589.244198   0.084323
# 6    61591.314952   8.813894
# 5    66232.272487   9.478028
# 4      313.278613   0.044831
# 1     9804.810409   1.403097
# 3       66.162356   0.009468
# 2    20868.177324   2.986296
# 0      305.103199   0.043661

# %%
#viz function - generates graphics based on the two columns and the title
def vis_share(column1, column2, title):
    #Visualization
    plt.bar(column1,column2)
    plt.axis([0, 6, 0, 100])
    plt.xticks(rotation=90)
    plt.xlabel('Frequency')
    plt.ylabel('Share, %')
    subtitle = "Data Source: PSRC HHTS 2019"
    plt.suptitle(title, y=1.02, fontsize=18)
    plt.title(subtitle, fontsize=10)

# %%
#vis_share(tnc_gender_seattle["label"],tnc_freq_seattle["Share"],"Frequency of Rideshre Use, Seattle")

# %%
tnc_gender_seattle1
# Out:
#                                   TNC_Freq   Gender     hh_wt_2019      Share
# 24                         I never do this     Male  171008.218122  24.471767
# 23                         I never do this   Female  122558.957386  17.538539
# 22                         I never do this  Another     994.845054   0.142365
# 20  I do this, but not in the past 30 days     Male   28104.842347   4.021884
# 19  I do this, but not in the past 30 days   Female   53204.426540   7.613706
# 18  I do this, but not in the past 30 days  Another    1300.914208   0.186165
# 17                           6-7 days/week     Male    1297.804503   0.185720
# 16                           6-7 days/week   Female     998.088721   0.142829
# 15                           6-7 days/week  Another       0.000000   0.000000
# 13                             5 days/week     Male     676.900699   0.096866
# 12                             5 days/week   Female    1118.513374   0.160062
# 10                           2-4 days/week     Male   18920.847794   2.707628
# 9                            2-4 days/week   Female   16955.429595   2.426371
# 8                            2-4 days/week  Another      25.946069   0.003713
# 6            1-3 times in the past 30 days     Male   61591.314952   8.813894
# 5            1-3 times in the past 30 days   Female   66232.272487   9.478028
# 4            1-3 times in the past 30 days  Another     313.278613   0.044831
# 1                               1 day/week   Female    9804.810409   1.403097
# 2                               1 day/week     Male   20868.177324   2.986296
# 0                               1 day/week  Another     305.103199   0.043661

# %%
tnc_gender_seattle1=tnc_gender_seattle[tnc_gender_seattle.Gender != 'Prefer not to answer']
tnc_gender_seattle1=tnc_gender_seattle1[tnc_gender_seattle1.TNC_Freq != 'Missing:Skip logic']
tnc_gender_seattle1=tnc_gender_seattle1[tnc_gender_seattle1.TNC_Freq != 'Missing: Non-response']

# %%
tnc_gender_seattle1.pivot("TNC_Freq","Gender","Share")
# Out:
# Gender                                   Another     Female       Male
# TNC_Freq
# 1 day/week                              0.043661   1.403097   2.986296
# 1-3 times in the past 30 days           0.044831   9.478028   8.813894
# 2-4 days/week                           0.003713   2.426371   2.707628
# 5 days/week                                  NaN   0.160062   0.096866
# 6-7 days/week                           0.000000   0.142829   0.185720
# I do this, but not in the past 30 days  0.186165   7.613706   4.021884
# I never do this                         0.142365  17.538539  24.471767

# %%
tnc_gender_seattle1.pivot("TNC_Freq","Gender","Share").plot.bar(figsize=(10, 10))

# %%
# income
person_detail_df = lookup_codes(person_detail_Seattle,'mode_freq_5','TNC_Freq')
person_detail_df2 = lookup_codes(person_detail_df,'hhincome_broad','Income')
#person_detail_df2 =person_detail_df2.rename(columns = {'label_x':'Income', 'label_y':'TNC_Freq'})
tnc_income_seattle =person_detail_df2.groupby(['Income','TNC_Freq']).sum()['hh_wt_2019'].reset_index()
tnc_income_seattle['Share'] = 0
for i in range(0,len(tnc_income_seattle.index)):
    tnc_income_seattle.iloc[i,3] =tnc_income_seattle.iloc[i,2]/ (tnc_income_seattle['hh_wt_2019'].sum())*100

# %%
tnc_income_seattle.sort_values(by=['TNC_Freq', "Income"], inplace=True, ascending=False)
tnc_income_seattle
# Out:
#                   Income                                TNC_Freq  \
# 51         Under $25,000                      Missing:Skip logic
# 42  Prefer not to answer                      Missing:Skip logic
# 35       $75,000-$99,999                      Missing:Skip logic
# 26       $50,000-$74,999                      Missing:Skip logic
# 17       $25,000-$49,999                      Missing:Skip logic
# 8       $100,000 or more                      Missing:Skip logic
# 50         Under $25,000                   Missing: Non-response
# 34       $75,000-$99,999                   Missing: Non-response
# 25       $50,000-$74,999                   Missing: Non-response
# 16       $25,000-$49,999                   Missing: Non-response
# 7       $100,000 or more                   Missing: Non-response
# 49         Under $25,000                         I never do this
# 41  Prefer not to answer                         I never do this
# 33       $75,000-$99,999                         I never do this
# 24       $50,000-$74,999                         I never do this
# 15       $25,000-$49,999                         I never do this
# 6       $100,000 or more                         I never do this
# 48         Under $25,000  I do this, but not in the past 30 days
# 40  Prefer not to answer  I do this, but not in the past 30 days
# 32       $75,000-$99,999  I do this, but not in the past 30 days
# 23       $50,000-$74,999  I do this, but not in the past 30 days
# 14       $25,000-$49,999  I do this, but not in the past 30 days
# 5       $100,000 or more  I do this, but not in the past 30 days
# 47         Under $25,000                           6-7 days/week
# 31       $75,000-$99,999                           6-7 days/week
# 22       $50,000-$74,999                           6-7 days/week
# 13       $25,000-$49,999                           6-7 days/week
# 4       $100,000 or more                           6-7 days/week
# 46         Under $25,000                             5 days/week
# 39  Prefer not to answer                             5 days/week
# 30       $75,000-$99,999                             5 days/week
# 21       $50,000-$74,999                             5 days/week
# 12       $25,000-$49,999                             5 days/week
# 3       $100,000 or more                             5 days/week
# 45         Under $25,000                           2-4 days/week
# 38  Prefer not to answer                           2-4 days/week
# 29       $75,000-$99,999                           2-4 days/week
# 20       $50,000-$74,999                           2-4 days/week
# 11       $25,000-$49,999                           2-4 days/week
# 2       $100,000 or more                           2-4 days/week
# 44         Under $25,000           1-3 times in the past 30 days
# 37  Prefer not to answer           1-3 times in the past 30 days
# 28       $75,000-$99,999           1-3 times in the past 30 days
# 19       $50,000-$74,999           1-3 times in the past 30 days
# 10       $25,000-$49,999           1-3 times in the past 30 days
# 1       $100,000 or more           1-3 times in the past 30 days
# 43         Under $25,000                              1 day/week
# 36  Prefer not to answer                              1 day/week
# 27       $75,000-$99,999                              1 day/week
# 18       $50,000-$74,999                              1 day/week
# 9        $25,000-$49,999                              1 day/week
# 0       $100,000 or more                              1 day/week
#
#       hh_wt_2019      Share
# 51  35228.900005   5.041357
# 42   1120.812130   0.160391
# 35  10943.186079   1.566001
# 26   1875.637217   0.268409
# 17   4985.336202   0.713416
# 8   56443.095701   8.077169
# 50    618.823757   0.088555
# 34     30.450797   0.004358
# 25    192.930041   0.027609
# 16     73.011315   0.010448
# 7     251.978612   0.036059
# 49  59580.971717   8.526208
# 41  44611.757619   6.384071
# 33  41106.540524   5.882464
# 24  30775.394149   4.404047
# 15  28737.096855   4.112361
# 6   97603.885071  13.967396
# 48   3806.369990   0.544702
# 40   3719.325933   0.532246
# 32   6677.320912   0.955544
# 23   8691.591220   1.243792
# 14  23057.819704   3.299640
# 5   38303.231824   5.481302
# 47    301.482309   0.043143
# 31     25.946069   0.003713
# 22    948.324327   0.135708
# 13     10.428845   0.001492
# 4    1009.711674   0.144493
# 46      0.000000   0.000000
# 39      0.000000   0.000000
# 30      4.663282   0.000667
# 21    399.759625   0.057207
# 12    286.820419   0.041045
# 3    1177.934909   0.168566
# 45    998.490731   0.142887
# 38    996.849987   0.142652
# 29   1815.697854   0.259832
# 20   7881.003816   1.127794
# 11    387.990144   0.055523
# 2   24347.065096   3.484135
# 44   1880.979380   0.269174
# 37   1278.756642   0.182994
# 28  10500.124117   1.502598
# 19  10728.636342   1.535299
# 10  14153.903466   2.025464
# 1   90183.710303  12.905548
# 43   1438.618076   0.205870
# 36    869.622959   0.124446
# 27   4422.035114   0.632806
# 18   3021.400575   0.432371
# 9    1227.584162   0.175671
# 0   20064.992402   2.871358

# %%
tnc_income_seattle1=tnc_income_seattle[tnc_income_seattle.Income != 'Prefer not to answer']
tnc_income_seattle1=tnc_income_seattle1[tnc_income_seattle1.TNC_Freq != 'Missing:Skip logic']
tnc_income_seattle1=tnc_income_seattle1[tnc_income_seattle1.TNC_Freq != 'Missing: Non-response']

# %%
tnc_income_seattle1.head()
# Out:
#               Income         TNC_Freq    hh_wt_2019     Share
# 49     Under $25,000  I never do this  59580.971717  0.000000
# 33   $75,000-$99,999  I never do this  41106.540524  0.000000
# 24   $50,000-$74,999  I never do this  30775.394149  0.084323
# 15   $25,000-$49,999  I never do this  28737.096855  0.142829
# 6   $100,000 or more  I never do this  97603.885071  1.123876

# %%
pd.__version__

# %%
df3 = tnc_income_seattle1[["Income", "TNC_Freq", "Share"]]
#df3.index = df3.Income
#df4 = df3[["TNC_Freq", "Share"]]

# %%
df3
# Out:
#               Income                                TNC_Freq     Share
# 49     Under $25,000                         I never do this  0.000000
# 33   $75,000-$99,999                         I never do this  0.000000
# 24   $50,000-$74,999                         I never do this  0.084323
# 15   $25,000-$49,999                         I never do this  0.142829
# 6   $100,000 or more                         I never do this  1.123876
# 48     Under $25,000  I do this, but not in the past 30 days  0.000000
# 32   $75,000-$99,999  I do this, but not in the past 30 days  0.000000
# 23   $50,000-$74,999  I do this, but not in the past 30 days  0.003713
# 14   $25,000-$49,999  I do this, but not in the past 30 days  0.185720
# 5   $100,000 or more  I do this, but not in the past 30 days  0.093757
# 47     Under $25,000                           6-7 days/week  0.000000
# 31   $75,000-$99,999                           6-7 days/week  0.043661
# 22   $50,000-$74,999                           6-7 days/week  2.426371
# 13   $25,000-$49,999                           6-7 days/week  0.186165
# 4   $100,000 or more                           6-7 days/week  0.073271
# 46     Under $25,000                             5 days/week  0.000000
# 30   $75,000-$99,999                             5 days/week  2.986296
# 21   $50,000-$74,999                             5 days/week  2.707628
# 12   $25,000-$49,999                             5 days/week  7.613706
# 3   $100,000 or more                             5 days/week  0.014483
# 45     Under $25,000                           2-4 days/week  0.000000
# 29   $75,000-$99,999                           2-4 days/week  0.009468
# 20   $50,000-$74,999                           2-4 days/week  0.075111
# 11   $25,000-$49,999                           2-4 days/week  4.021884
# 2   $100,000 or more                           2-4 days/week  8.758388
# 44     Under $25,000           1-3 times in the past 30 days  0.000000
# 28   $75,000-$99,999           1-3 times in the past 30 days  1.403097
# 19   $50,000-$74,999           1-3 times in the past 30 days  0.160062
# 10   $25,000-$49,999           1-3 times in the past 30 days  0.235472
# 1   $100,000 or more           1-3 times in the past 30 days  6.825500
# 43     Under $25,000                              1 day/week  0.000000
# 27   $75,000-$99,999                              1 day/week  0.044831
# 18   $50,000-$74,999                              1 day/week  0.096866
# 9    $25,000-$49,999                              1 day/week  0.142365
# 0   $100,000 or more                              1 day/week  0.228373

# %%
#df4.plot.bar()
df3.groupby(by=["TNC_Freq", "Income"]).mean().unstack().plot.bar(figsize=(10, 10))

# %%
df3.groupby(by=["TNC_Freq", "Income"]).mean().unstack()
# Out:
#                                                   Share                  \
# Income                                 $100,000 or more $25,000-$49,999
# TNC_Freq
# 1 day/week                                     2.871358        0.175671
# 1-3 times in the past 30 days                 12.905548        2.025464
# 2-4 days/week                                  3.484135        0.055523
# 5 days/week                                    0.168566        0.041045
# 6-7 days/week                                  0.144493        0.001492
# I do this, but not in the past 30 days         5.481302        3.299640
# I never do this                               13.967396        4.112361
#
#                                                                         \
# Income                                 $50,000-$74,999 $75,000-$99,999
# TNC_Freq
# 1 day/week                                    0.432371        0.632806
# 1-3 times in the past 30 days                 1.535299        1.502598
# 2-4 days/week                                 1.127794        0.259832
# 5 days/week                                   0.057207        0.000667
# 6-7 days/week                                 0.135708        0.003713
# I do this, but not in the past 30 days        1.243792        0.955544
# I never do this                               4.404047        5.882464
#
#
# Income                                 Under $25,000
# TNC_Freq
# 1 day/week                                  0.205870
# 1-3 times in the past 30 days               0.269174
# 2-4 days/week                               0.142887
# 5 days/week                                 0.000000
# 6-7 days/week                               0.043143
# I do this, but not in the past 30 days      0.544702
# I never do this                             8.526208

# %%
df3.pivot("Income", "TNC_Freq").plot.bar(figsize=(10, 10))

# %%
#by education
def get_table(newMobility_variable,newMobility_variable_name,variable,variable_name):
    person_detail_df = lookup_codes(person_detail_Seattle,newMobility_variable,newMobility_variable_name)
    person_detail_df2 = lookup_codes(person_detail_df,variable, variable_name)
    df =person_detail_df2.groupby([variable_name,newMobility_variable_name]).sum()['hh_wt_2019'].reset_index()
    df['Share'] = 0
    for i in range(0,len(df.index)):
        df.iloc[i,3] =df.iloc[i,2]/ (df['hh_wt_2019'].sum())*100
    df=df[df[variable_name] != 'Prefer not to answer']
    df=df[df[newMobility_variable_name] != 'Missing:Skip logic']
    df=df[df[newMobility_variable_name] != 'Missing: Non-response']
    return df

# %%
education_seattle=get_table('mode_freq_5','TNC_Freq','education','education_var')
education_seattle.pivot('education_var', "TNC_Freq","Share").plot.bar(figsize=(10, 10))

# %%
#Age Group-TNC
education_seattle=get_table('mode_freq_5','TNC_Freq','age','age_var')
education_seattle.pivot('age_var', "TNC_Freq","Share").plot.bar(figsize=(10, 10))

# %%
#Auto Ownership-TNC
autoOwn_seattle=get_table('mode_freq_5','TNC_Freq','vehicle_count','vehicle_count_var')
autoOwn_seattle.pivot('vehicle_count_var', "TNC_Freq","Share").plot.bar(figsize=(10, 10))

# %%
#Number of Children-TNC
def get_table_quant(newMobility_variable,newMobility_variable_name,variable):
    person_detail_df = lookup_codes(person_detail_Seattle,newMobility_variable,newMobility_variable_name)
    #person_detail_df2 = lookup_codes(person_detail_df,variable, variable_name)
    df =person_detail_df.groupby([variable,newMobility_variable_name]).sum()['hh_wt_2019'].reset_index()
    df['Share'] = 0
    for i in range(0,len(df.index)):
        df.iloc[i,3] =df.iloc[i,2]/ (df['hh_wt_2019'].sum())*100
    df=df[df[variable] != 'Prefer not to answer']
    df=df[df[newMobility_variable_name] != 'Missing:Skip logic']
    df=df[df[newMobility_variable_name] != 'Missing: Non-response']
    return df

# %%
children_seattle=get_table_quant('mode_freq_5','TNC_Freq','numchildren')
children_seattle.pivot('numchildren', "TNC_Freq","Share").plot.bar(figsize=(10, 10))

# %%
#by race
race_seattle=get_table('mode_freq_5','TNC_Freq','race','race_var')
#race_seattle.pivot('race_var', "TNC_Freq","Share").plot.bar(figsize=(10, 10))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-139-7023c7d5f0ba> in <module>
#       1 #by race
# ----> 2 race_seattle=get_table('mode_freq_5','TNC_Freq','race','race_var')
#       3 #race_seattle.pivot('race_var', "TNC_Freq","Share").plot.bar(figsize=(10, 10))
#
# <ipython-input-138-28a78eb5c5d2> in get_table(newMobility_variable, newMobility_variable_name, variable, variable_name)
#       2 def get_table(newMobility_variable,newMobility_variable_name,variable,variable_name):
#       3     person_detail_df = lookup_codes(person_detail_Seattle,newMobility_variable,newMobility_variable_name)
# ----> 4     person_detail_df2 = lookup_codes(person_detail_df,variable, variable_name)
#       5     df =person_detail_df2.groupby([variable_name,newMobility_variable_name]).sum()['hh_wt_2019'].reset_index()
#       6     df['Share'] = 0
#
# <ipython-input-49-d9b5907b8eae> in lookup_codes(grouped_total, item, name)
#       1 def lookup_codes(grouped_total, item,name):
#       2     values=codebook_values.loc[codebook_values['variable']==item]
# ----> 3     variable =codebook_variables.loc[codebook_variables['variable']==item, 'description'].values[0]
#       4     missing_values_df = pd.DataFrame({'variable': [item, item, item],'value':[-9999,-9998, 995], 'label':
#       5                                          ['Missing:Technical Error', 'Missing: Non-response', 'Missing:Skip logic']})
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
person_detail_Seattle[person_detail_Seattle.]
# Out:
#         recid       hhid  survey_year  cityofredmond  cityofseattle  psrc  \
# 2         NaN   17100024         2017            0.0              1     0
# 3         NaN   17100024         2017            0.0              1     0
# 4         NaN   17100024         2017            0.0              1     0
# 5         NaN   17100052         2017            0.0              1     0
# 6         NaN   17100059         2017            0.0              1     0
# ...       ...        ...          ...            ...            ...   ...
# 11935  3075.0  191026431         2019            NaN              1     0
# 11936  3076.0  191038667         2019            NaN              1     0
# 11937  3076.0  191038667         2019            NaN              1     0
# 11938  3076.0  191038667         2019            NaN              1     0
# 11939  3076.0  191038667         2019            NaN              1     0
#
#        hhgroup  sample_segment  sample_lat  sample_lng  ... num_tripsperson  \
# 2            2              51         NaN         NaN  ...               8
# 3            2              51         NaN         NaN  ...               4
# 4            2              51         NaN         NaN  ...               2
# 5            2              51         NaN         NaN  ...               5
# 6            1              50         NaN         NaN  ...              33
# ...        ...             ...         ...         ...  ...             ...
# 11935        1              54     47.6901    -122.371  ...              24
# 11936        1              52     47.6067    -122.296  ...              16
# 11937        1              52     47.6067    -122.296  ...              45
# 11938        1              52     47.6067    -122.296  ...              40
# 11939        1              52     47.6067    -122.296  ...              23
#
#        nwkdaysperson  hh_wt_revisedperson  hh_day_wt_revisedperson  \
# 2                  1            26.224981                26.224981
# 3                  1            26.224981                26.224981
# 4                  1            26.224981                26.224981
# 5                  1            25.692826                25.692826
# 6                  3            47.768728                15.922909
# ...              ...                  ...                      ...
# 11935              3                  NaN                      NaN
# 11936              4                  NaN                      NaN
# 11937              4                  NaN                      NaN
# 11938              4                  NaN                      NaN
# 11939              4                  NaN                      NaN
#
#       initial_expansion_factor_combinedperson  hh_wt_combinedperson  \
# 2                                   47.543561             12.391381
# 3                                   47.543561             12.391381
# 4                                   47.543561             12.391381
# 5                                   47.543561             12.128225
# 6                                   86.469251             92.238608
# ...                                       ...                   ...
# 11935                               25.510708              6.507708
# 11936                               46.880854             12.218658
# 11937                               46.880854             12.218658
# 11938                               46.880854             12.218658
# 11939                               46.880854             12.218658
#
#        initial_expansion_factor_2019person  hh_wt_2019person  \
# 2                                 0.000000          0.000000
# 3                                 0.000000          0.000000
# 4                                 0.000000          0.000000
# 5                                 0.000000          0.000000
# 6                                 0.000000          0.000000
# ...                                    ...               ...
# 11935                            52.957346        112.181703
# 11936                            97.319355         25.354003
# 11937                            97.319355         25.354003
# 11938                            97.319355         25.354003
# 11939                            97.319355         25.354003
#
#        hh_day_wt_combinedperson  hh_day_wt_2019person
# 2                     12.391381              0.000000
# 3                     12.391381              0.000000
# 4                     12.391381              0.000000
# 5                     12.128225              0.000000
# 6                     30.746203              0.000000
# ...                         ...                   ...
# 11935                  2.169236             37.393901
# 11936                  3.054665              6.338501
# 11937                  3.054665              6.338501
# 11938                  3.054665              6.338501
# 11939                  3.054665              6.338501
#
# [6838 rows x 252 columns]
