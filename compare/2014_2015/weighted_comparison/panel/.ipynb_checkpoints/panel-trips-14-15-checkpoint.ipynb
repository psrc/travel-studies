# %%
import pandas as pd
import numpy as np
from IPython.display import display, display_pretty, Javascript, HTML
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
from matplotlib.backends.backend_pdf import PdfPages


# Show charts in notebook
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# adding an empty line to test

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# Load 2014 and 2015 survey household data
person14 = pd.read_csv(r'J:\Projects\Surveys\HHTravel\Survey2014\Data\Export\Release 3\General Release\Unzipped\2014-pr3-hhsurvey-persons.csv')
person15 = pd.read_csv(r'J:\Projects\Surveys\HHTravel\Survey2015\Data\Person\3_PSRC2015_Person_2015-07-27_v1.2.csv')
# Out:
# C:\Users\Brice\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\io\parsers.py:1159: DtypeWarning: Columns (107) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
# Load 2014 and 2015 survey household data
trips14 = pd.read_csv(r'J:\Projects\Surveys\HHTravel\Survey2014\Data\Export\Release 3\General Release\Unzipped\2014-pr3-hhsurvey-trips.csv')
trips15 = pd.read_csv(r'J:\Projects\Surveys\HHTravel\Survey2015\Data\Trips\4_PSRC2015_Trip_2015-07-27_v1.6.csv')

# %%
# Join 2014 and 2015 datasets; creates dataframe with 14 and 15 suffixes as column names
# panel_trips = pd.merge(trips14, trips15, on='personID', suffixes=['_14','_15'])

# %%
# Compare 2014 to 2015

# %%
def add_labels(df, fields, labels):
    '''adds frequency labels for a set of like fields'''

    for field in fields:
        df[field + '_label'] = df[field]
        df[field].fillna(0,inplace=True)
        df[field + '_label'] = ([labels[x] for x in df[field]])

# %%
labels = {  1: "SOV",
            2: "HOV",
            3: "HOV",
            4: "SOV",
            5: "HOV",
            6: "Bicycle",
            7: "Walk",
            8: "Bus",
            9: "Train+Streetcar",
           10: "Ferry",
           11: "Train+Streetcar",
           12: "Other",
           13: "Taxi",
           14: "Other",
           15: "Private bus/shuttle",
           16: "Other",
           17: "Other",
           -99: "NA"
}

add_labels(trips15,['mode'], labels)
add_labels(trips14,['mode'], labels)

# %%
labels = {  1: "Home",
            2: "Work",
            3: "Work Other",
            4: "Grocery",
            5: "Shopping",
            6: "School",
            7: "Medical",
            8: "Personal Business",
            9: "Drop-off/pick-up",
           10: "Exercise",
           11: "Eat",
           12: "Social",
           13: "Recreational",
           14: "Community Event",
           15: "Transfer Mode",
           16: "Other",
           -99: "NA"
}

add_labels(trips15,['d_purpose'], labels)
add_labels(trips14,['d_purpose'], labels)

# %%
labels = {
    0.0: 'NA',
    1: 'Regular taxi',
    2: 'Rideshare',
    -99: 'NA'
}

add_labels(trips15,['taxi_type'], labels)
add_labels(trips14,['taxi_type'], labels)

# %% [markdown]
# # Mode

# %%
# Get the distribtion of each mode totals
mode14dist = trips14.groupby('mode_label').count()['personID']/trips14.groupby('mode_label').count()['personID'].sum()
mode15dist = trips15.groupby('mode_label').count()['personID']/trips15.groupby('mode_label').count()['personID'].sum()

df = pd.DataFrame([mode14dist, mode15dist]).T
df.columns=['2014','2015']
df.drop('NA', inplace=True)

# %%
# Get the distribtion of each mode totals
mode14dist = trips14.groupby('mode_label').count()['personID']/trips14.groupby('mode_label').count()['personID'].sum()
mode15dist = trips15.groupby('mode_label').count()['personID']/trips15.groupby('mode_label').count()['personID'].sum()

df = pd.DataFrame([mode14dist, mode15dist]).T
df.columns=['2014','2015']

# %%
# Plot the distributions

# Drop some columns 
df.drop(['Taxi','Private bus/shuttle','Other','NA'],inplace=True)
plt.figure()
df.plot(kind='barh', alpha=0.8, title='Mode Distribution')

# %% [markdown]
# # Taxi

# %%
# How many taxi trips in a rideshare vehicle?
taxi14 = trips14.groupby('taxi_type_label').count()['personID']
taxi15 = trips15.groupby('taxi_type_label').count()['personID']

df = pd.DataFrame([taxi14,taxi15]).T
df.columns = ['2014','2015']
df.drop(['NA'],inplace=True)    # drop the NA responses
df['change, 14->15'] = df['2015'] - df['2014']
df.to_clipboard()

# %%
df.index.name = " "    # clear index name to remove as x-axis label
df = df[['2014','2015']].T
df.index.name = " "    # clear index name to remove as x-axis label
plt.figure()
df.plot(kind='bar', alpha=0.8, title='Total Taxi Trips by Type', figsize=(7,7), fontsize=12, )

# %%
# Show distribution too
taxi_trips14 = trips14.query('taxi_type == 1 or taxi_type == 2')
taxi_trips15 = trips15.query('taxi_type == 1 or taxi_type == 2')

taxi14 = taxi_trips14.groupby('taxi_type_label').count()['personID']/taxi_trips14.groupby('mode_label').count()['personID'].sum()
taxi15 = taxi_trips15.groupby('taxi_type_label').count()['personID']/taxi_trips15.groupby('mode_label').count()['personID'].sum()

df = pd.DataFrame([taxi14,taxi15]).T
df.columns = ['2014','2015']

# %%
print len(trips15.query('mode == 13'))
print len(taxi_trips15)
print "-----"
print len(trips14.query('mode == 13'))
print len(taxi_trips14)
# Out:
# 31
# 32
# -----
# 87
# 96

# %%
taxi_trips14.groupby('taxi_type_label').count()['personID']
# Out:
# taxi_type_label
# Regular taxi       39
# Rideshare          57
# Name: personID, dtype: int64

# %%
taxi_trips15.groupby('taxi_type_label').count()['personID']
# Out:
# taxi_type_label
# Regular taxi       13
# Rideshare          19
# Name: personID, dtype: int64

# %%
taxi_trips14.groupby('mode_label').count()['personID'].sum()
# Out:
# 96L

# %%
df.index.name = " "    # clear index name to remove as x-axis label
df = df[['2014','2015']]
df.index.name = " "    # clear index name to remove as x-axis label
plt.figure()
df.plot(kind='bar', alpha=0.8, title='Taxi Trips by Type (Distribution)', figsize=(5,5), fontsize=12, )

# %%
# Total number of trips is still very small, but notable increase in rideshare usage over taxi.

# %% [markdown]
# # Trip Purpose

# %%
# Get the distribtion of each mode totals
mode14dist = trips14.groupby('d_purpose_label').count()['personID']/trips14.groupby('d_purpose_label').count()['personID'].sum()
mode15dist = trips15.groupby('d_purpose_label').count()['personID']/trips15.groupby('d_purpose_label').count()['personID'].sum()

df = pd.DataFrame([mode14dist, mode15dist]).T
df.columns=['2014','2015']

# %%
# Plot the distributions

df.index.name = ""    # clear index name to remove as x-axis label
plt.figure()
df.plot(kind='barh', alpha=0.8, title='Trip Purpose Distribution', figsize=(10, 8))

# %% [markdown]
# # Trip Characteristics

# %%
# Histograms of travel time 
df14 = trips14.query('mode == 1')
df15 = trips15.query('mode == 1')

# SOV
plt.figure()

# Normalized histogram
(df14.query('0 < gdist < 30'))['gdist'].hist(color='b', alpha=0.5, bins=100, normed=True, legend=True)
(df15.query('0 < gdist < 30'))['gdist'].hist(color='r', alpha=0.5, bins=100, normed=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-184-7d3bbcc686c1> in <module>()
#       7
#       8 # Normalized histogram
# ----> 9 (df14.query('0 < gdist < 30'))['gdist'].hist(color='b', alpha=0.5, bins=100, normed=True, legend=True)
#      10 (df15.query('0 < gdist < 30'))['gdist'].hist(color='r', alpha=0.5, bins=100, normed=True)
#
# C:\Users\Brice\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\tools\plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2817         values = self.dropna().values
#    2818
# -> 2819         ax.hist(values, bins=bins, **kwds)
#    2820         ax.grid(grid)
#    2821         axes = np.array([ax])
#
# C:\Users\Brice\AppData\Local\Continuum\Anaconda\lib\site-packages\matplotlib\axes\_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    5886             if patch:
#    5887                 p = patch[0]
# -> 5888                 p.update(kwargs)
#    5889                 if lbl is not None:
#    5890                     p.set_label(lbl)
#
# C:\Users\Brice\AppData\Local\Continuum\Anaconda\lib\site-packages\matplotlib\artist.pyc in update(self, props)
#     755             func = getattr(self, 'set_' + k, None)
#     756             if func is None or not six.callable(func):
# --> 757                 raise AttributeError('Unknown property %s' % k)
#     758             func(v)
#     759             changed = True
#
# AttributeError: Unknown property legend

# %%
# WALK

# %%
plt.figure()
df14 = panel_trips.query('mode_14 == 7')
df15 = panel_trips.query('mode_15 == 7')

(df14.query('0 < gdist_14 < 3'))['gdist_14'].hist(color='b', alpha=0.5, bins=100)
(df15.query('0 < gdist_15 < 3'))['gdist_15'].hist(color='r', alpha=0.5, bins=100)

# %%
# Bus
plt.figure()
df14 = panel_trips.query('mode_14 == 8')
df15 = panel_trips.query('mode_15 == 8')

(df14.query('0 < gdist_14 < 30'))['gdist_14'].hist(color='b', alpha=0.5, bins=100)
(df15.query('0 < gdist_15 < 30'))['gdist_15'].hist(color='r', alpha=0.5, bins=100)

# %%
# Bike
plt.figure()
df14 = panel_trips.query('mode_14 == 6')
df15 = panel_trips.query('mode_15 == 6')

(df14.query('0 < gdist_14 < 15'))['gdist_14'].hist(color='b', alpha=0.5, bins=40)
(df15.query('0 < gdist_15 < 15'))['gdist_15'].hist(color='r', alpha=0.5, bins=40)

# %%
# Taxi
plt.figure()
df14 = panel_trips.query('mode_14 == 13')
df15 = panel_trips.query('mode_15 == 13')

(df14.query('0 < gdist_14 < 25'))['gdist_14'].hist(color='b', alpha=0.5, bins=10)
(df15.query('0 < gdist_15 < 25'))['gdist_15'].hist(color='r', alpha=0.5, bins=10)

# %% [markdown]
# # Transit Ridership

# %%
# Find households who rode lines that were affected by KC Metro cuts in late 2014

# %%
deleted_routes = [7,19,47,48,61,62,139,152,161,173,202,203,205,209,210,211,213,215,
                 243,250,260,265,280,306,909,919,927,935]
revised_routes = [24,27,30,33,48,178,200,201,204,208,212,236,238,249,312,331,903,931]

# %%
deleted14
# Out:
#       recordID_14   hhid_14    personID     tripID_14  pernum_14  tripnum_14  \
# 5775       A05200  14100639  1410063901  141006390102          1           2
# 5776       A05200  14100639  1410063901  141006390102          1           2
# 5777       A05200  14100639  1410063901  141006390102          1           2
# 5778       A05200  14100639  1410063901  141006390102          1           2
# 5779       A05200  14100639  1410063901  141006390102          1           2
# 5780       A05200  14100639  1410063901  141006390102          1           2
# 5781       A05200  14100639  1410063901  141006390102          1           2
# 6280       A05692  14100699  1410069901  141006990101          1           1
# 6281       A05692  14100699  1410069901  141006990101          1           1
# 6282       A05692  14100699  1410069901  141006990101          1           1
# 6283       A05692  14100699  1410069901  141006990101          1           1
# 6284       A05692  14100699  1410069901  141006990101          1           1
# 6285       A05692  14100699  1410069901  141006990101          1           1
# 6286       A05692  14100699  1410069901  141006990101          1           1
# 6287       A05693  14100699  1410069901  141006990102          1           2
# 6288       A05693  14100699  1410069901  141006990102          1           2
# 6289       A05693  14100699  1410069901  141006990102          1           2
# 6290       A05693  14100699  1410069901  141006990102          1           2
# 6291       A05693  14100699  1410069901  141006990102          1           2
# 6292       A05693  14100699  1410069901  141006990102          1           2
# 6293       A05693  14100699  1410069901  141006990102          1           2
# 6298       A05696  14100699  1410069902  141006990203          2           3
# 6299       A05696  14100699  1410069902  141006990203          2           3
# 6300       A05697  14100699  1410069902  141006990204          2           4
# 6301       A05697  14100699  1410069902  141006990204          2           4
# 6302       A05698  14100699  1410069903  141006990301          3           1
# 6303       A05698  14100699  1410069903  141006990301          3           1
# 6304       A05698  14100699  1410069903  141006990301          3           1
# 6305       A05699  14100699  1410069903  141006990302          3           2
# 6306       A05699  14100699  1410069903  141006990302          3           2
# ...           ...       ...         ...           ...        ...         ...
# 40823      A35805  14104334  1410433401  141043340101          1           1
# 40824      A35805  14104334  1410433401  141043340101          1           1
# 44301      A38662  14104677  1410467701  141046770101          1           1
# 44302      A38662  14104677  1410467701  141046770101          1           1
# 44303      A38663  14104677  1410467701  141046770102          1           2
# 44304      A38663  14104677  1410467701  141046770102          1           2
# 49259      A43518  14105238  1410523801  141052380101          1           1
# 49260      A43518  14105238  1410523801  141052380101          1           1
# 52455      A46010  14105526  1410552603  141055260302          3           2
# 52456      A46010  14105526  1410552603  141055260302          3           2
# 52457      A46010  14105526  1410552603  141055260302          3           2
# 52458      A46010  14105526  1410552603  141055260302          3           2
# 56671      A49586  14105953  1410595301  141059530101          1           1
# 56672      A49586  14105953  1410595301  141059530101          1           1
# 56675      A49589  14105953  1410595301  141059530103          1           3
# 56676      A49589  14105953  1410595301  141059530103          1           3
# 57318      A50189  14106023  1410602302  141060230201          2           1
# 57319      A50189  14106023  1410602302  141060230201          2           1
# 57320      A50189  14106023  1410602302  141060230201          2           1
# 57321      A50189  14106023  1410602302  141060230201          2           1
# 57322      A50190  14106023  1410602302  141060230202          2           2
# 57323      A50190  14106023  1410602302  141060230202          2           2
# 57324      A50190  14106023  1410602302  141060230202          2           2
# 57325      A50190  14106023  1410602302  141060230202          2           2
# 58297      A50814  14106091  1410609101  141060910101          1           1
# 58298      A50814  14106091  1410609101  141060910101          1           1
# 58299      A50814  14106091  1410609101  141060910101          1           1
# 58300      A50814  14106091  1410609101  141060910101          1           1
# 58301      A50814  14106091  1410609101  141060910101          1           1
# 58302      A50814  14106091  1410609101  141060910101          1           1
#
#       total_trip  last_14  ocnty        ocity         ...          member8_15  \
# 5775           4      NaN      1      SEATTLE         ...                 NaN
# 5776           4      NaN      1      SEATTLE         ...                 NaN
# 5777           4      NaN      1      SEATTLE         ...                 NaN
# 5778           4      NaN      1      SEATTLE         ...                 NaN
# 5779           4      NaN      1      SEATTLE         ...                 NaN
# 5780           4      NaN      1      SEATTLE         ...                 NaN
# 5781           4      NaN      1      SEATTLE         ...                 NaN
# 6280           2      NaN      1  WOODINVILLE         ...                 NaN
# 6281           2      NaN      1  WOODINVILLE         ...                 NaN
# 6282           2      NaN      1  WOODINVILLE         ...                 NaN
# 6283           2      NaN      1  WOODINVILLE         ...                 NaN
# 6284           2      NaN      1  WOODINVILLE         ...                 NaN
# 6285           2      NaN      1  WOODINVILLE         ...                 NaN
# 6286           2      NaN      1  WOODINVILLE         ...                 NaN
# 6287           2        1      1     BELLEVUE         ...                 NaN
# 6288           2        1      1     BELLEVUE         ...                 NaN
# 6289           2        1      1     BELLEVUE         ...                 NaN
# 6290           2        1      1     BELLEVUE         ...                 NaN
# 6291           2        1      1     BELLEVUE         ...                 NaN
# 6292           2        1      1     BELLEVUE         ...                 NaN
# 6293           2        1      1     BELLEVUE         ...                 NaN
# 6298           4      NaN      1  WOODINVILLE         ...                 NaN
# 6299           4      NaN      1  WOODINVILLE         ...                 NaN
# 6300           4        1      1      BOTHELL         ...                 NaN
# 6301           4        1      1      BOTHELL         ...                 NaN
# 6302           2      NaN      1  WOODINVILLE         ...                 NaN
# 6303           2      NaN      1  WOODINVILLE         ...                 NaN
# 6304           2      NaN      1  WOODINVILLE         ...                 NaN
# 6305           2        1      1      BOTHELL         ...                 NaN
# 6306           2        1      1      BOTHELL         ...                 NaN
# ...          ...      ...    ...          ...         ...                 ...
# 40823          6      NaN      1     BELLEVUE         ...                 NaN
# 40824          6      NaN      1     BELLEVUE         ...                 NaN
# 44301          2      NaN      1      REDMOND         ...                 NaN
# 44302          2      NaN      1      REDMOND         ...                 NaN
# 44303          2        1      1      REDMOND         ...                 NaN
# 44304          2        1      1      REDMOND         ...                 NaN
# 49259          4      NaN      1     BELLEVUE         ...                 NaN
# 49260          4      NaN      1     BELLEVUE         ...                 NaN
# 52455          2        1      2    BREMERTON         ...                 NaN
# 52456          2        1      2    BREMERTON         ...                 NaN
# 52457          2        1      2    BREMERTON         ...                 NaN
# 52458          2        1      2    BREMERTON         ...                 NaN
# 56671          3      NaN      1     BELLEVUE         ...                 NaN
# 56672          3      NaN      1     BELLEVUE         ...                 NaN
# 56675          3        1      1     BELLEVUE         ...                 NaN
# 56676          3        1      1     BELLEVUE         ...                 NaN
# 57318          2      NaN      1      REDMOND         ...                 NaN
# 57319          2      NaN      1      REDMOND         ...                 NaN
# 57320          2      NaN      1      REDMOND         ...                 NaN
# 57321          2      NaN      1      REDMOND         ...                 NaN
# 57322          2        1      1      REDMOND         ...                 NaN
# 57323          2        1      1      REDMOND         ...                 NaN
# 57324          2        1      1      REDMOND         ...                 NaN
# 57325          2        1      1      REDMOND         ...                 NaN
# 58297          4      NaN      4   MARYSVILLE         ...                 NaN
# 58298          4      NaN      4   MARYSVILLE         ...                 NaN
# 58299          4      NaN      4   MARYSVILLE         ...                 NaN
# 58300          4      NaN      4   MARYSVILLE         ...                 NaN
# 58301          4      NaN      4   MARYSVILLE         ...                 NaN
# 58302          4      NaN      4   MARYSVILLE         ...                 NaN
#
#       prepop  childunder5_originaltripid child_under5  mode_14_label  \
# 5775       0                         NaN            0            Bus
# 5776       0                         NaN            0            Bus
# 5777       0                         NaN            0            Bus
# 5778       0                         NaN            0            Bus
# 5779       0                         NaN            0            Bus
# 5780       0                         NaN            0            Bus
# 5781       0                         NaN            0            Bus
# 6280       0                         NaN            0            Bus
# 6281       0                         NaN            0            Bus
# 6282       0                         NaN            0            Bus
# 6283       0                         NaN            0            Bus
# 6284       0                         NaN            0            Bus
# 6285       0                         NaN            0            Bus
# 6286       0                         NaN            0            Bus
# 6287       0                         NaN            0            Bus
# 6288       0                         NaN            0            Bus
# 6289       0                         NaN            0            Bus
# 6290       0                         NaN            0            Bus
# 6291       0                         NaN            0            Bus
# 6292       0                         NaN            0            Bus
# 6293       0                         NaN            0            Bus
# 6298       0                         NaN            0            Bus
# 6299       0                         NaN            0            Bus
# 6300       0                         NaN            0            Bus
# 6301       0                         NaN            0            Bus
# 6302       0                         NaN            0            Bus
# 6303       1                         NaN            0            Bus
# 6304       1                         NaN            0            Bus
# 6305       0                         NaN            0            Bus
# 6306       1                         NaN            0            Bus
# ...      ...                         ...          ...            ...
# 40823      0                         NaN            0            Bus
# 40824      0                         NaN            0            Bus
# 44301      0                         NaN            0            Bus
# 44302      0                         NaN            0            Bus
# 44303      0                         NaN            0            Bus
# 44304      0                         NaN            0            Bus
# 49259      0                         NaN            0            Bus
# 49260      0                         NaN            0            Bus
# 52455      0                         NaN            0          Ferry
# 52456      0                         NaN            0          Ferry
# 52457      0                         NaN            0          Ferry
# 52458      0                         NaN            0          Ferry
# 56671      0                         NaN            0            Bus
# 56672      0                         NaN            0            Bus
# 56675      0                         NaN            0            Bus
# 56676      0                         NaN            0            Bus
# 57318      0                         NaN            0            Bus
# 57319      0                         NaN            0            Bus
# 57320      0                         NaN            0            Bus
# 57321      0                         NaN            0            Bus
# 57322      0                         NaN            0            Bus
# 57323      0                         NaN            0            Bus
# 57324      0                         NaN            0            Bus
# 57325      0                         NaN            0            Bus
# 58297      0                         NaN            0            Bus
# 58298      0                         NaN            0            Bus
# 58299      0                         NaN            0            Bus
# 58300      0                         NaN            0            Bus
# 58301      0                         NaN            0            Bus
# 58302      0                         NaN            0            Bus
#
#       mode_15_label  d_purpose_14_label d_purpose_15_label  \
# 5775            Bus                Home               Work
# 5776           Walk                Home  Personal Business
# 5777           Walk                Home               Work
# 5778            Bus                Home               Home
# 5779            SOV                Home           Exercise
# 5780            SOV                Home  Personal Business
# 5781            SOV                Home               Home
# 6280        Bicycle                Work               Work
# 6281        Bicycle                Work               Home
# 6282            SOV                Work   Drop-off/pick-up
# 6283            HOV                Work       Recreational
# 6284            SOV                Work             Social
# 6285            SOV                Work   Drop-off/pick-up
# 6286            HOV                Work               Home
# 6287        Bicycle                Home               Work
# 6288        Bicycle                Home               Home
# 6289            SOV                Home   Drop-off/pick-up
# 6290            HOV                Home       Recreational
# 6291            SOV                Home             Social
# 6292            SOV                Home   Drop-off/pick-up
# 6293            HOV                Home               Home
# 6298            Bus   Personal Business               Work
# 6299            Bus   Personal Business               Home
# 6300            Bus                Home               Work
# 6301            Bus                Home               Home
# 6302          Other   Personal Business             School
# 6303            HOV   Personal Business           Exercise
# 6304            HOV   Personal Business               Home
# 6305          Other                Home             School
# 6306            HOV                Home           Exercise
# ...             ...                 ...                ...
# 40823           Bus                Work               Home
# 40824           Bus                Work               Home
# 44301           Bus                Work               Work
# 44302           Bus                Work               Home
# 44303           Bus                Home               Work
# 44304           Bus                Home               Home
# 49259           Bus   Personal Business               Work
# 49260           Bus   Personal Business               Home
# 52455           Bus                Home             School
# 52456           Bus                Home               Home
# 52457           SOV                Home               Work
# 52458           SOV                Home               Home
# 56671           SOV                 Eat               Work
# 56672           SOV                 Eat               Home
# 56675           SOV                Home               Work
# 56676           SOV                Home               Home
# 57318           SOV                Work           Exercise
# 57319           SOV                Work               Home
# 57320           HOV                Work    Community Event
# 57321           HOV                Work               Home
# 57322           SOV                Home           Exercise
# 57323           SOV                Home               Home
# 57324           HOV                Home    Community Event
# 57325           HOV                Home               Home
# 58297           SOV                Work               Work
# 58298           Bus                Work               Work
# 58299           Bus                Work               Work
# 58300           Bus                Work               Home
# 58301           Bus                Work               Home
# 58302           SOV                Work               Home
#
#        taxi_type_14_label  taxi_type_15_label
# 5775                   NA                  NA
# 5776                   NA                  NA
# 5777                   NA                  NA
# 5778                   NA                  NA
# 5779                   NA                  NA
# 5780                   NA                  NA
# 5781                   NA                  NA
# 6280                   NA                  NA
# 6281                   NA                  NA
# 6282                   NA                  NA
# 6283                   NA                  NA
# 6284                   NA                  NA
# 6285                   NA                  NA
# 6286                   NA                  NA
# 6287                   NA                  NA
# 6288                   NA                  NA
# 6289                   NA                  NA
# 6290                   NA                  NA
# 6291                   NA                  NA
# 6292                   NA                  NA
# 6293                   NA                  NA
# 6298                   NA                  NA
# 6299                   NA                  NA
# 6300                   NA                  NA
# 6301                   NA                  NA
# 6302                   NA                  NA
# 6303                   NA                  NA
# 6304                   NA                  NA
# 6305                   NA                  NA
# 6306                   NA                  NA
# ...                   ...                 ...
# 40823                  NA                  NA
# 40824                  NA                  NA
# 44301                  NA                  NA
# 44302                  NA                  NA
# 44303                  NA                  NA
# 44304                  NA                  NA
# 49259                  NA                  NA
# 49260                  NA                  NA
# 52455                  NA                  NA
# 52456                  NA                  NA
# 52457                  NA                  NA
# 52458                  NA                  NA
# 56671                  NA                  NA
# 56672                  NA                  NA
# 56675                  NA                  NA
# 56676                  NA                  NA
# 57318                  NA                  NA
# 57319                  NA                  NA
# 57320                  NA                  NA
# 57321                  NA                  NA
# 57322                  NA                  NA
# 57323                  NA                  NA
# 57324                  NA                  NA
# 57325                  NA                  NA
# 58297                  NA                  NA
# 58298                  NA                  NA
# 58299                  NA                  NA
# 58300                  NA                  NA
# 58301                  NA                  NA
# 58302                  NA                  NA
#
# [165 rows x 180 columns]

# %%
deleted14 = panel_trips[panel_trips['transitline1_14'].isin(deleted_routes)]
deleted15 = panel_trips[panel_trips['transitline1_15'].isin(deleted_routes)]

revised14 = panel_trips[panel_trips['transitline1_14'].isin(revised_routes)]
revised15 = panel_trips[panel_trips['transitline1_15'].isin(revised_routes)]

# %%
deleted14_hh_index = deleted14.groupby('hhid_14').count().index
df = panel_trips[panel_trips['hhid_14'].isin(deleted14_hh_index)]

len(df)
# Out:
# 627

# %%
# len(df['mode_14'])
df[['tripID_14','tripID_15','mode_14','mode_15']]
# Out:
#           tripID_14     tripID_15  mode_14  mode_15
# 5768   141006390101  141006390101        8        8
# 5769   141006390101  141006390102        8        7
# 5770   141006390101  141006390103        8        7
# 5771   141006390101  141006390104        8        8
# 5772   141006390101  141006390105        8        1
# 5773   141006390101  141006390106        8        1
# 5774   141006390101  141006390107        8        1
# 5775   141006390102  141006390101        8        8
# 5776   141006390102  141006390102        8        7
# 5777   141006390102  141006390103        8        7
# 5778   141006390102  141006390104        8        8
# 5779   141006390102  141006390105        8        1
# 5780   141006390102  141006390106        8        1
# 5781   141006390102  141006390107        8        1
# 5782   141006390103  141006390101        3        8
# 5783   141006390103  141006390102        3        7
# 5784   141006390103  141006390103        3        7
# 5785   141006390103  141006390104        3        8
# 5786   141006390103  141006390105        3        1
# 5787   141006390103  141006390106        3        1
# 5788   141006390103  141006390107        3        1
# 5789   141006390104  141006390101        3        8
# 5790   141006390104  141006390102        3        7
# 5791   141006390104  141006390103        3        7
# 5792   141006390104  141006390104        3        8
# 5793   141006390104  141006390105        3        1
# 5794   141006390104  141006390106        3        1
# 5795   141006390104  141006390107        3        1
# 6280   141006990101  141006990101        8        6
# 6281   141006990101  141006990102        8        6
# ...             ...           ...      ...      ...
# 58299  141060910101  141060910103        8        8
# 58300  141060910101  141060910104        8        8
# 58301  141060910101  141060910105        8        8
# 58302  141060910101  141060910106        8        1
# 58303  141060910102  141060910101        8        1
# 58304  141060910102  141060910102        8        8
# 58305  141060910102  141060910103        8        8
# 58306  141060910102  141060910104        8        8
# 58307  141060910102  141060910105        8        8
# 58308  141060910102  141060910106        8        1
# 58309  141060910103  141060910101        1        1
# 58310  141060910103  141060910102        1        8
# 58311  141060910103  141060910103        1        8
# 58312  141060910103  141060910104        1        8
# 58313  141060910103  141060910105        1        8
# 58314  141060910103  141060910106        1        1
# 58315  141060910104  141060910101        1        1
# 58316  141060910104  141060910102        1        8
# 58317  141060910104  141060910103        1        8
# 58318  141060910104  141060910104        1        8
# 58319  141060910104  141060910105        1        8
# 58320  141060910104  141060910106        1        1
# 58321  141060910201  141060910201        1        1
# 58322  141060910201  141060910202        1        1
# 58323  141060910202  141060910201        1        1
# 58324  141060910202  141060910202        1        1
# 58325  141060910203  141060910201        1        1
# 58326  141060910203  141060910202        1        1
# 58327  141060910204  141060910201        1        1
# 58328  141060910204  141060910202        1        1
#
# [627 rows x 4 columns]

# %%
# Get household id of those who used deleted routes in 2014
deleted14_hh_index = deleted14.groupby('hhid_14').count().index
df = panel_trips[panel_trips['hhid_14'].isin(deleted14_hh_index)]

# What is their mode share in 2014 vs 2015?
# Get the distribtion of each mode totals
mode14dist = df.groupby('mode_14_label').count()['personID']/df.groupby('mode_14_label').count()['personID'].sum()
mode15dist = df.groupby('mode_15_label').count()['personID']/df.groupby('mode_15_label').count()['personID'].sum()

df = pd.DataFrame([mode14dist, mode15dist]).T
df.columns=['2014','2015']

# %%
# Plot the distributions

df.index.name = ""    # clear index name to remove as x-axis label
plt.figure()
df.plot(kind='bar', alpha=0.8, title='Mode Choice', figsize=(10, 8))

# %%
panel_trips.groupby('transitline1_14').count()
# Out:
#                  recordID_14  hhid_14  personID  tripID_14  pernum_14  \
# transitline1_14
# 3                          7        7         7          7          7
# 14                         7        7         7          7          7
# 21                         2        2         2          2          2
# 23                         2        2         2          2          2
# 27                        22       22        22         22         22
# 28                        26       26        26         26         26
# 30                         6        6         6          6          6
# 43                         8        8         8          8          8
# 47                         6        6         6          6          6
# 50                         5        5         5          5          5
# 51                        11       11        11         11         11
# 52                        11       11        11         11         11
# 54                         2        2         2          2          2
# 57                        12       12        12         12         12
# 58                         3        3         3          3          3
# 61                        11       11        11         11         11
# 62                        26       26        26         26         26
# 63                        50       50        50         50         50
# 64                       174      174       174        174        174
# 65                       105      105       105        105        105
# 66                        21       21        21         21         21
# 67                        60       60        60         60         60
# 68                        40       40        40         40         40
# 69                        43       43        43         43         43
# 70                        61       61        61         61         61
# 71                        59       59        59         59         59
# 72                       179      179       179        179        179
# 73                         8        8         8          8          8
# 74                        35       35        35         35         35
# 75                        26       26        26         26         26
# ...                      ...      ...       ...        ...        ...
# 385                       12       12        12         12         12
# 386                        9        9         9          9          9
# 390                        5        5         5          5          5
# 391                       24       24        24         24         24
# 392                       30       30        30         30         30
# 393                        6        6         6          6          6
# 394                       34       34        34         34         34
# 397                        8        8         8          8          8
# 398                       12       12        12         12         12
# 399                      107      107       107        107        107
# 400                      109      109       109        109        109
# 401                       54       54        54         54         54
# 402                       24       24        24         24         24
# 404                        8        8         8          8          8
# 405                       10       10        10         10         10
# 406                       10       10        10         10         10
# 409                       15       15        15         15         15
# 411                       30       30        30         30         30
# 412                        4        4         4          4          4
# 416                      116      116       116        116        116
# 417                       19       19        19         19         19
# 418                       18       18        18         18         18
# 419                       84       84        84         84         84
# 421                       40       40        40         40         40
# 423                        9        9         9          9          9
# 426                       52       52        52         52         52
# 427                       50       50        50         50         50
# 429                        8        8         8          8          8
# 448                      155      155       155        155        155
# 449                       40       40        40         40         40
#
#                  tripnum_14  total_trip  last_14  ocnty  ocity  \
# transitline1_14
# 3                         7           7        7      7      7
# 14                        7           7        0      7      7
# 21                        2           2        2      2      2
# 23                        2           2        0      2      2
# 27                       22          22        5     22     22
# 28                       26          26        0     26     26
# 30                        6           6        0      6      6
# 43                        8           8        4      8      8
# 47                        6           6        0      6      6
# 50                        5           5        2      5      5
# 51                       11          11        0     11     11
# 52                       11          11        0     11     11
# 54                        2           2        0      2      2
# 57                       12          12        6     12     12
# 58                        3           3        0      3      3
# 61                       11          11       11     11     11
# 62                       26          26       13     26     26
# 63                       50          50       17     50     50
# 64                      174         174       41    174    174
# 65                      105         105       33    105    105
# 66                       21          21        7     21     21
# 67                       60          60       16     60     60
# 68                       40          40        2     40     40
# 69                       43          43        5     43     43
# 70                       61          61        9     61     61
# 71                       59          59       11     59     59
# 72                      179         179       11    179    179
# 73                        8           8        0      8      8
# 74                       35          35        9     35     35
# 75                       26          26        0     26     26
# ...                     ...         ...      ...    ...    ...
# 385                      12          12        6     12     12
# 386                       9           9        0      9      9
# 390                       5           5        0      5      5
# 391                      24          24        0     24     24
# 392                      30          30        7     30     30
# 393                       6           6        0      6      6
# 394                      34          34        8     34     34
# 397                       8           8        0      8      8
# 398                      12          12        6     12     12
# 399                     107         107       23    107    107
# 400                     109         109       21    109    109
# 401                      54          54        0     54     54
# 402                      24          24        0     24     24
# 404                       8           8        0      8      8
# 405                      10          10        5     10     10
# 406                      10          10        0     10     10
# 409                      15          15        0     15     15
# 411                      30          30        2     30     30
# 412                       4           4        2      4      4
# 416                     116         116       32    116    116
# 417                      19          19        9     19     19
# 418                      18          18        0     18     18
# 419                      84          84       26     84     84
# 421                      40          40       14     40     40
# 423                       9           9        0      9      9
# 426                      52          52       13     52     52
# 427                      50          50        6     50     50
# 429                       8           8        8      8      8
# 448                     155         155       44    155    155
# 449                      40          40        4     40     40
#
#                         ...          member8_15  prepop  \
# transitline1_14         ...
# 3                       ...                   0       7
# 14                      ...                   0       7
# 21                      ...                   0       2
# 23                      ...                   0       2
# 27                      ...                   0      22
# 28                      ...                   0      26
# 30                      ...                   0       6
# 43                      ...                   0       8
# 47                      ...                   0       6
# 50                      ...                   0       5
# 51                      ...                   0      11
# 52                      ...                   0      11
# 54                      ...                   0       2
# 57                      ...                   0      12
# 58                      ...                   0       3
# 61                      ...                   0      11
# 62                      ...                   0      26
# 63                      ...                   0      50
# 64                      ...                   0     174
# 65                      ...                   0     105
# 66                      ...                   0      21
# 67                      ...                   0      60
# 68                      ...                   0      40
# 69                      ...                   0      43
# 70                      ...                   0      61
# 71                      ...                   0      59
# 72                      ...                   0     179
# 73                      ...                   0       8
# 74                      ...                   0      35
# 75                      ...                   0      26
# ...                     ...                 ...     ...
# 385                     ...                   0      12
# 386                     ...                   0       9
# 390                     ...                   0       5
# 391                     ...                   0      24
# 392                     ...                   0      30
# 393                     ...                   0       6
# 394                     ...                   0      34
# 397                     ...                   0       8
# 398                     ...                   0      12
# 399                     ...                   0     107
# 400                     ...                   0     109
# 401                     ...                   0      54
# 402                     ...                   0      24
# 404                     ...                   0       8
# 405                     ...                   0      10
# 406                     ...                   0      10
# 409                     ...                   0      15
# 411                     ...                   0      30
# 412                     ...                   0       4
# 416                     ...                   0     116
# 417                     ...                   0      19
# 418                     ...                   0      18
# 419                     ...                   0      84
# 421                     ...                   0      40
# 423                     ...                   0       9
# 426                     ...                   0      52
# 427                     ...                   0      50
# 429                     ...                   0       8
# 448                     ...                   0     155
# 449                     ...                   0      40
#
#                  childunder5_originaltripid  child_under5  mode_14_label  \
# transitline1_14
# 3                                         0             7              7
# 14                                        0             7              7
# 21                                        0             2              2
# 23                                        0             2              2
# 27                                        0            22             22
# 28                                        0            26             26
# 30                                        0             6              6
# 43                                        0             8              8
# 47                                        0             6              6
# 50                                        0             5              5
# 51                                        0            11             11
# 52                                        0            11             11
# 54                                        0             2              2
# 57                                        0            12             12
# 58                                        0             3              3
# 61                                        0            11             11
# 62                                        0            26             26
# 63                                        0            50             50
# 64                                        0           174            174
# 65                                        0           105            105
# 66                                        0            21             21
# 67                                        0            60             60
# 68                                        0            40             40
# 69                                        0            43             43
# 70                                        0            61             61
# 71                                        0            59             59
# 72                                        0           179            179
# 73                                        0             8              8
# 74                                        0            35             35
# 75                                        0            26             26
# ...                                     ...           ...            ...
# 385                                       0            12             12
# 386                                       0             9              9
# 390                                       0             5              5
# 391                                       0            24             24
# 392                                       0            30             30
# 393                                       0             6              6
# 394                                       0            34             34
# 397                                       0             8              8
# 398                                       0            12             12
# 399                                       0           107            107
# 400                                       0           109            109
# 401                                       0            54             54
# 402                                       0            24             24
# 404                                       0             8              8
# 405                                       0            10             10
# 406                                       0            10             10
# 409                                       0            15             15
# 411                                       0            30             30
# 412                                       0             4              4
# 416                                       0           116            116
# 417                                       0            19             19
# 418                                       0            18             18
# 419                                       0            84             84
# 421                                       0            40             40
# 423                                       0             9              9
# 426                                       0            52             52
# 427                                       0            50             50
# 429                                       0             8              8
# 448                                       0           155            155
# 449                                       0            40             40
#
#                  mode_15_label  d_purpose_14_label  d_purpose_15_label  \
# transitline1_14
# 3                            7                   7                   7
# 14                           7                   7                   7
# 21                           2                   2                   2
# 23                           2                   2                   2
# 27                          22                  22                  22
# 28                          26                  26                  26
# 30                           6                   6                   6
# 43                           8                   8                   8
# 47                           6                   6                   6
# 50                           5                   5                   5
# 51                          11                  11                  11
# 52                          11                  11                  11
# 54                           2                   2                   2
# 57                          12                  12                  12
# 58                           3                   3                   3
# 61                          11                  11                  11
# 62                          26                  26                  26
# 63                          50                  50                  50
# 64                         174                 174                 174
# 65                         105                 105                 105
# 66                          21                  21                  21
# 67                          60                  60                  60
# 68                          40                  40                  40
# 69                          43                  43                  43
# 70                          61                  61                  61
# 71                          59                  59                  59
# 72                         179                 179                 179
# 73                           8                   8                   8
# 74                          35                  35                  35
# 75                          26                  26                  26
# ...                        ...                 ...                 ...
# 385                         12                  12                  12
# 386                          9                   9                   9
# 390                          5                   5                   5
# 391                         24                  24                  24
# 392                         30                  30                  30
# 393                          6                   6                   6
# 394                         34                  34                  34
# 397                          8                   8                   8
# 398                         12                  12                  12
# 399                        107                 107                 107
# 400                        109                 109                 109
# 401                         54                  54                  54
# 402                         24                  24                  24
# 404                          8                   8                   8
# 405                         10                  10                  10
# 406                         10                  10                  10
# 409                         15                  15                  15
# 411                         30                  30                  30
# 412                          4                   4                   4
# 416                        116                 116                 116
# 417                         19                  19                  19
# 418                         18                  18                  18
# 419                         84                  84                  84
# 421                         40                  40                  40
# 423                          9                   9                   9
# 426                         52                  52                  52
# 427                         50                  50                  50
# 429                          8                   8                   8
# 448                        155                 155                 155
# 449                         40                  40                  40
#
#                  taxi_type_14_label  taxi_type_15_label
# transitline1_14
# 3                                 7                   7
# 14                                7                   7
# 21                                2                   2
# 23                                2                   2
# 27                               22                  22
# 28                               26                  26
# 30                                6                   6
# 43                                8                   8
# 47                                6                   6
# 50                                5                   5
# 51                               11                  11
# 52                               11                  11
# 54                                2                   2
# 57                               12                  12
# 58                                3                   3
# 61                               11                  11
# 62                               26                  26
# 63                               50                  50
# 64                              174                 174
# 65                              105                 105
# 66                               21                  21
# 67                               60                  60
# 68                               40                  40
# 69                               43                  43
# 70                               61                  61
# 71                               59                  59
# 72                              179                 179
# 73                                8                   8
# 74                               35                  35
# 75                               26                  26
# ...                             ...                 ...
# 385                              12                  12
# 386                               9                   9
# 390                               5                   5
# 391                              24                  24
# 392                              30                  30
# 393                               6                   6
# 394                              34                  34
# 397                               8                   8
# 398                              12                  12
# 399                             107                 107
# 400                             109                 109
# 401                              54                  54
# 402                              24                  24
# 404                               8                   8
# 405                              10                  10
# 406                              10                  10
# 409                              15                  15
# 411                              30                  30
# 412                               4                   4
# 416                             116                 116
# 417                              19                  19
# 418                              18                  18
# 419                              84                  84
# 421                              40                  40
# 423                               9                   9
# 426                              52                  52
# 427                              50                  50
# 429                               8                   8
# 448                             155                 155
# 449                              40                  40
#
# [180 rows x 179 columns]
